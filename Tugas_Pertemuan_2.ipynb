# %% [markdown]
# <a href="https://colab.research.google.com/github/irunn/Pembelajaran_Mesin/blob/main/Tugas_Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = '/content/drive/MyDrive/Colab Notebooks/cbb23.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#             TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0         Kansas   B12  36  28  113.8   92.3   0.9177   52.6   47.0  17.5
# 1         Purdue   B10  35  29  117.9   93.7   0.9333   51.8   47.2  17.2
# 2        Alabama   SEC  37  31  116.1   89.0   0.9548   52.1   41.3  18.7
# 3        Houston  Amer  37  33  117.3   90.3   0.9532   52.3   42.7  15.4
# 4          Texas   B12  38  29  116.1   91.8   0.9371   53.3   48.1  16.3
# ..           ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 358       Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 359      Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 360  Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 361          UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 362  North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
#      ...   FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# ...

# %%
data.head(5)
# Out:
#       TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 0   Kansas   B12  36  28  113.8   92.3   0.9177   52.6   47.0  17.5  ...
# 1   Purdue   B10  35  29  117.9   93.7   0.9333   51.8   47.2  17.2  ...
# 2  Alabama   SEC  37  31  116.1   89.0   0.9548   52.1   41.3  18.7  ...
# 3  Houston  Amer  37  33  117.3   90.3   0.9532   52.3   42.7  15.4  ...
# 4    Texas   B12  38  29  116.1   91.8   0.9371   53.3   48.1  16.3  ...
#
#     FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0  29.8  31.1  53.0  47.2  34.7  31.0   69.0  10.1         R32   1.0
# 1  37.2  19.2  54.1  47.2  32.2  31.3   63.9   9.4         R64   1.0
# 2  36.6  32.6  53.8  40.8  33.5  28.3   72.6  10.2         S16   1.0
# 3  28.9  35.7  53.1  43.4  34.0  27.9   63.4   8.0         S16   1.0
# 4  30.5  33.7  54.0  47.9  34.7  32.4   68.5   7.5          E8   2.0
#
# [5 rows x 23 columns]

# %%
print(data.dtypes)
# Out:
# TEAM           object
# CONF           object
# G               int64
# W               int64
# ADJOE         float64
# ADJDE         float64
# BARTHAG       float64
# EFG_O         float64
# EFG_D         float64
# TOR           float64
# TORD          float64
# ORB           float64
# DRB           float64
# FTR           float64
# FTRD          float64
# 2P_O          float64
# 2P_D          float64
# 3P_O          float64
# 3P_D          float64
# ADJ_T         float64
# WAB           float64
# POSTSEASON     object
# SEED          float64
# dtype: object

# %%
data_1 = data.iloc[:,2:]
data_1
# Out:
#       G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD   ORB  ...   FTR  \
# 0    36  28  113.8   92.3   0.9177   52.6   47.0  17.5  20.2  28.7  ...  29.8
# 1    35  29  117.9   93.7   0.9333   51.8   47.2  17.2  15.4  38.4  ...  37.2
# 2    37  31  116.1   89.0   0.9548   52.1   41.3  18.7  15.8  34.2  ...  36.6
# 3    37  33  117.3   90.3   0.9532   52.3   42.7  15.4  21.1  37.1  ...  28.9
# 4    38  29  116.1   91.8   0.9371   53.3   48.1  16.3  22.1  28.3  ...  30.5
# ..   ..  ..    ...    ...      ...    ...    ...   ...   ...   ...  ...   ...
# 358  34  27  119.9  109.6   0.7369   56.3   52.9  13.6  18.3  29.8  ...  34.4
# 359  33  27  111.4   97.3   0.8246   55.5   49.3  16.0  18.9  25.3  ...  26.2
# 360  34  28  107.1   94.6   0.8065   51.7   44.0  19.3  16.3  28.9  ...  35.6
# 361  38  29  112.4   97.0   0.8453   50.3   47.3  17.3  19.3  35.8  ...  35.7
# 362  36  31  110.0   93.8   0.8622   51.2   44.5  19.8  19.9  33.4  ...  31.0
#
# ...

# %%
data_2 = data.drop(data.columns[4],axis=1)
data_2
# Out:
#             TEAM  CONF   G   W  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD  ...  \
# 0         Kansas   B12  36  28   92.3   0.9177   52.6   47.0  17.5  20.2  ...
# 1         Purdue   B10  35  29   93.7   0.9333   51.8   47.2  17.2  15.4  ...
# 2        Alabama   SEC  37  31   89.0   0.9548   52.1   41.3  18.7  15.8  ...
# 3        Houston  Amer  37  33   90.3   0.9532   52.3   42.7  15.4  21.1  ...
# 4          Texas   B12  38  29   91.8   0.9371   53.3   48.1  16.3  22.1  ...
# ..           ...   ...  ..  ..    ...      ...    ...    ...   ...   ...  ...
# 358       Toledo   MAC  34  27  109.6   0.7369   56.3   52.9  13.6  18.3  ...
# 359      Liberty  ASun  33  27   97.3   0.8246   55.5   49.3  16.0  18.9  ...
# 360  Utah Valley   WAC  34  28   94.6   0.8065   51.7   44.0  19.3  16.3  ...
# 361          UAB  CUSA  38  29   97.0   0.8453   50.3   47.3  17.3  19.3  ...
# 362  North Texas  CUSA  36  31   93.8   0.8622   51.2   44.5  19.8  19.9  ...
#
# ...

# %%
data.describe()
# Out:
#                 G           W       ADJOE       ADJDE     BARTHAG       EFG_O  \
# count  363.000000  363.000000  363.000000  363.000000  363.000000  363.000000
# mean    31.482094   17.115702  104.132507  104.132507    0.494561   50.335813
# std      2.570892    6.249230    6.688726    6.192639    0.249735    2.696393
# min     21.000000    3.000000   86.900000   87.500000    0.032800   42.300000
# 25%     30.000000   13.000000   99.500000  100.000000    0.274650   48.650000
# 50%     31.000000   17.000000  103.600000  104.500000    0.477000   50.500000
# 75%     33.000000   22.000000  108.900000  108.700000    0.722400   52.000000
# max     39.000000   35.000000  123.200000  120.200000    0.964300   58.200000
#
#             EFG_D         TOR        TORD         ORB         DRB         FTR  \
# count  363.000000  363.000000  363.000000  363.000000  363.000000  363.000000
# mean    50.531956   18.248209   18.175482   28.375207   28.556749   31.595592
# ...

# %%
korelasi = data.corr()
# Out:
# <ipython-input-40-2908e2138e8d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   korelasi = data.corr()

# %%
data.loc[:,"ADJOE":].corr()
# Out:
# <ipython-input-41-dce5aa2f6255>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"ADJOE":].corr()
#             ADJOE     ADJDE   BARTHAG     EFG_O     EFG_D       TOR      TORD  \
# ADJOE    1.000000 -0.563024  0.884596  0.714165 -0.375629 -0.574087 -0.066845
# ADJDE   -0.563024  1.000000 -0.866748 -0.217540  0.808567  0.242616 -0.305870
# BARTHAG  0.884596 -0.866748  1.000000  0.536973 -0.650216 -0.465865  0.122757
# EFG_O    0.714165 -0.217540  0.536973  1.000000 -0.136617 -0.373854 -0.117606
# EFG_D   -0.375629  0.808567 -0.650216 -0.136617  1.000000  0.147304 -0.069674
# TOR     -0.574087  0.242616 -0.465865 -0.373854  0.147304  1.000000  0.180573
# TORD    -0.066845 -0.305870  0.122757 -0.117606 -0.069674  0.180573  1.000000
# ...

# %% [markdown]
# # ADJOE vs ADJDE

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='ADJOE', y='ADJDE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/content/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-be46700d-f87c-4bce-b30a-476151192836" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be46700d-f87c-4bce-b30a-476151192836">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "korean drama"
# Out:
# ...
# ref                                                                  title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# chanoncharuchinda/top-100-korean-drama-mydramalist                   Top 100 Korean Drama (MyDramaList)                   58KB  2023-08-05 09:23:44           4122         74  1.0
# ahbab911/top-250-korean-dramas-kdrama-dataset                        Top 250 Korean Dramas (KDrama) Dataset               90KB  2023-01-21 10:06:24           2537         60  1.0
# chanoncharuchinda/korean-drama-2015-23-actor-and-reviewmydramalist   Korean Drama from 2015-2023 with Actors & Reviews     8MB  2023-08-25 08:45:36           1148         39  1.0
# ...

# %%
# !kaggle datasets download varunmusunuru/mydramalist-movies-dramas
# Out:
# ...
#   0% 0.00/2.56M [00:00<?, ?B/s]
# 100% 2.56M/2.56M [00:00<00:00, 102MB/s]

# %%
# !unzip /content/mydramalist-movies-dramas.zip
# Out:
# Archive:  /content/mydramalist-movies-dramas.zip
#   inflating: MyDramaList_dramas.csv
#   inflating: MyDramaList_movies.csv

# %%
import pandas as pd

pd.read_csv('/content/MyDramaList_dramas.csv')
# Out:
#                         movie_title                                  link  \
# 0                    Move to Heaven                 /49231-move-to-heaven
# 1        Extraordinary Attorney Woo  /705723-strange-lawyer-woo-young-woo
# 2                    Flower of Evil                 /54625-flower-of-evil
# 3                   Nirvana in Fire                 /9025-nirvana-in-fire
# 4                 Hospital Playlist                /36269-doctor-playbook
# ...                             ...                                   ...
# 4967                  Man of Wisdom                  /33466-man-of-wisdom
# 4968                     No Regrets                      /2671-no-regrets
# 4969                    Home & Away                       /7830-home-away
# 4970              Kahon Maha Ratuek              /24003-kahon-maha-ratuek
# 4971  Kindaichi Shonen no Jikenbo 2   /2338-kindaichi-shonen-no-jikenbo-2
#
#       year                                   genre  \
# ...
